# %% [markdown]
# ### Read csv, use NLTK

# %%
# dependencies
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Read data into dataframe
file = os.path.join('..', 'Raw Data', 'train.csv' )
tweet_df = pd.read_csv(file, encoding='latin-1')
tweet_df.head()
# Out:
#    ItemID  Sentiment                                      SentimentText
# 0       1          0                       is so sad for my APL frie...
# 1       2          0                     I missed the New Moon trail...
# 2       3          1                            omg its already 7:30 :O
# 3       4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4       5          0           i think mi bf is cheating on me!!!   ...

# %%
# Check tweet length
tweet_df['pre_clean_len'] = [len(t) for t in tweet_df.SentimentText]
tweet_df.head()
# Out:
#    ItemID  Sentiment                                      SentimentText  \
# 0       1          0                       is so sad for my APL frie...
# 1       2          0                     I missed the New Moon trail...
# 2       3          1                            omg its already 7:30 :O
# 3       4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4       5          0           i think mi bf is cheating on me!!!   ...
#
#    pre_clean_len
# 0             61
# 1             51
# 2             37
# 3            132
# 4             53

# %%
# Preprocessing
import string 

# remove numbers
tweet_df['pre_clean_txt'] = [t.translate(str.maketrans('', '', string.digits)) for t in tweet_df.SentimentText]

# %%
# NLTK 
# to get dictionary run:
# >>> import nltk
# >>> nltk.download('words')
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.corpus import words as nltk_words
from nltk.stem.porter import PorterStemmer
from pattern.en import suggest

stop_words = stopwords.words('english')

# words into dictionary for fast lookup
engl_words = dict.fromkeys(nltk_words.words(), None)

#initializes porter
porter = PorterStemmer()

# use strip handle (tweeter) and reduce lenght (haaalooooo -> haaloo)
tknzr = TweetTokenizer(strip_handles=True, reduce_len=True)

ignore_words = {}
accepted_words = {}

def get_tokens(text):
    # text to tokens
    tokens = tknzr.tokenize(text)
    # remove punctuations, words to lower case
    alpha_tokens = [w.lower() for w in tokens if w.isalpha()]
    # do not use stop words
    ns_tokens = [w for w in alpha_tokens if not w in stop_words]
    # stemming
    st_tokens = [porter.stem(t) for t in ns_tokens]
    # only words in dictionary
    
    ow = []
    for w in ns_tokens:
        if(w in ignore_words):
            continue;
        if(w in accepted_words):
            ow.append(w)
            continue;
        if(w in engl_words):
            # word in dictionary
            ow.append(w)
            accepted_words[w] = True;
            continue
        sw = porter.stem(w)
        if(sw in accepted_words):
            ow.append(sw)
            continue;
        if(sw in engl_words):
            # stemmed word in dictionary
            ow.append(sw)
            accepted_words[sw] = True;
            continue
#        rw = suggest(w)[0]
#        if(rw[1] > 0.5):
#            ow.append(w)
#            accepted_words[w] = True;
#            continue
        ignore_words[w] = True
    return ow
#    return [w for w in st_tokens if w in engl_words]
    
tweet_df['Tokenized'] = [get_tokens(t) for t in tweet_df.pre_clean_txt]
tweet_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-e884e2727fc9> in <module>
#      65 #    return [w for w in st_tokens if w in engl_words]
#      66
# ---> 67 tweet_df['Tokenized'] = [get_tokens(t) for t in tweet_df.pre_clean_txt]
#      68 tweet_df.head(10)
#
# <ipython-input-32-e884e2727fc9> in <listcomp>(.0)
#      65 #    return [w for w in st_tokens if w in engl_words]
#      66
# ---> 67 tweet_df['Tokenized'] = [get_tokens(t) for t in tweet_df.pre_clean_txt]
#      68 tweet_df.head(10)
#
# <ipython-input-32-e884e2727fc9> in get_tokens(text)
#      56             accepted_words[sw] = True;
#      57             continue
# ---> 58         rw = suggest(w)[0]
#      59         if(rw[1] > 0.5):
#      60             ow.append(w)
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pattern\text\en\__init__.py in suggest(w)
#     205     """ Returns a list of (word, confidence)-tuples of spelling corrections.
#     206     """
# --> 207     return spelling.suggest(w)
#     208
#     209
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pattern\text\__init__.py in suggest(self, w)
#    2685         candidates = self._known([w]) \
#    2686                   or self._known(self._edit1(w)) \
# -> 2687                   or self._known(self._edit2(w)) \
#    2688                   or [w]
#    2689
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pattern\text\__init__.py in _edit2(self, w)
#    2664         # Of all spelling errors, 99% is covered by edit distance 2.
#    2665         # Only keep candidates that are actually known words (20% speedup).
# -> 2666         return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#    2667
#    2668     def _known(self, words=[]):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pattern\text\__init__.py in <genexpr>(.0)
#    2664         # Of all spelling errors, 99% is covered by edit distance 2.
#    2665         # Only keep candidates that are actually known words (20% speedup).
# -> 2666         return set(e2 for e1 in self._edit1(w) for e2 in self._edit1(e1) if e2 in self)
#    2667
#    2668     def _known(self, words=[]):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pattern\text\__init__.py in __contains__(self, *args)
#     380
#     381     def __contains__(self, *args):
# --> 382         return self._lazy("__contains__", *args)
#     383
#     384     def __getitem__(self, *args):
#
# ~\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\pattern\text\__init__.py in _lazy(self, method, *args)
#     361         pass
#     362
# --> 363     def _lazy(self, method, *args):
#     364         """ If the dictionary is empty, calls lazydict.load().
#     365             Replaces lazydict.method() with dict.method() and calls it.
#
# KeyboardInterrupt:

# %%
# https://vprusso.github.io/blog/2018/natural-language-processing-python-1/
# https://wordnet.princeton.edu/
# Words stat
from matplotlib import pyplot as plt
plt.figure(figsize=(15,10))

from nltk.probability import FreqDist

tokens_list =  [w for sublist in tweet_df.Tokenized for w in sublist]
tokens_list

# See https://en.wikipedia.org/wiki/Zipf%27s_law
fdist = nltk.FreqDist(tokens_list)
fdist.plot(50, cumulative=False, title=f"50 most common tokens (no stopwords or punctuation), out of {len(fdist.keys())}")

# %%
# Tweets to file
file = os.path.join('..', 'Output', 'tweets1.csv' )
out_df = tweet_df.loc[:, ['ItemID', 'Sentiment', 'Tokenized']]
out_df['Tokenized'] = out_df.Tokenized.apply(' '.join)
out_df.to_csv(file, index=False)

# Words to file
words_df = pd.DataFrame.from_dict(fdist.items())
words_df.columns = ['word','count']
words_df.sort_values(by=['word'], inplace=True)
words_df = words_df.reset_index(drop=True)
file = os.path.join('..', 'Output', 'words1.csv' )
words_df.to_csv(file)
words_df.head()
# Out:
#         word  count
# 0         aa      9
# 1        aam      1
# 2      aback      1
# 3    abandon      4
# 4  abandoned     10

# %%
# A bit of fun with visualization
from wordcloud import WordCloud

wordcloud = WordCloud(background_color='white').generate_from_frequencies(dict([t for t in fdist.items()]))
plt.figure(figsize=(15,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
# test tokenizers
test_txt = '@AnnOhio Hi Ann!!!!  *HUGE HUGS from FL*'
test_txt = ".. Omgaga. Im sooo  im gunna CRy. I've been at this dentist since 11.. I was suposed 2 just get a crown put on (30mins)..."
x = tknzr.tokenize(test_txt)
y = [w.lower() for w in x if w.isalpha()]
z = [porter.stem(t) for t in y]
print(x)
print(y)
print(z)
print(get_tokens(test_txt))
# Out:
# ['..', 'Omgaga', '.', 'Im', 'sooo', 'im', 'gunna', 'CRy', '.', "I've", 'been', 'at', 'this', 'dentist', 'since', '11', '..', 'I', 'was', 'suposed', '2', 'just', 'get', 'a', 'crown', 'put', 'on', '(', '30mins', ')', '...']
# ['omgaga', 'im', 'sooo', 'im', 'gunna', 'cry', 'been', 'at', 'this', 'dentist', 'since', 'i', 'was', 'suposed', 'just', 'get', 'a', 'crown', 'put', 'on']
# ['omgaga', 'im', 'sooo', 'im', 'gunna', 'cri', 'been', 'at', 'thi', 'dentist', 'sinc', 'i', 'wa', 'supos', 'just', 'get', 'a', 'crown', 'put', 'on']
# ['cry', 'dentist', 'since', 'get', 'crown', 'put']
