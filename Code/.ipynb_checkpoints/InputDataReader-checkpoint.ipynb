# %% [markdown]
# # Read csv

# %%
# dependencies
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Read data into dataframe
file = os.path.join('..', 'Raw Data', 'train.csv' )
tweet_df = pd.read_csv(file, encoding='latin-1')
tweet_df.head()
# Out:
#    ItemID  Sentiment                                      SentimentText
# 0       1          0                       is so sad for my APL frie...
# 1       2          0                     I missed the New Moon trail...
# 2       3          1                            omg its already 7:30 :O
# 3       4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4       5          0           i think mi bf is cheating on me!!!   ...

# %%
# check tweet length
tweet_df['pre_clean_len'] = [len(t) for t in tweet_df.SentimentText]
tweet_df.head()
# Out:
#    ItemID  Sentiment                                      SentimentText  \
# 0       1          0                       is so sad for my APL frie...
# 1       2          0                     I missed the New Moon trail...
# 2       3          1                            omg its already 7:30 :O
# 3       4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4       5          0           i think mi bf is cheating on me!!!   ...
#
#    pre_clean_len
# 0             61
# 1             51
# 2             37
# 3            132
# 4             53

# %%
# clean html tags
from bs4 import BeautifulSoup
import string  
import html
import re

# remove url
tweet_df['pre_clean_txt'] = [re.sub(r'http\S+', '', t) for t in tweet_df.SentimentText]

# unescape html characters
tweet_df['pre_clean_txt'] = [html.unescape(t) for t in tweet_df.pre_clean_txt]

# remove string.punctiation: !"#$%&'()*+, -./:;<=>?@[\]^_`{|}~
tweet_df['pre_clean_txt'] = [t.translate(str.maketrans('', '', string.punctuation)) for t in tweet_df.pre_clean_txt]

# remove numbers
tweet_df['pre_clean_txt'] = [t.translate(str.maketrans('', '', string.digits)) for t in tweet_df.pre_clean_txt]

# to lower case
tweet_df['pre_clean_txt'] = [t.lower() for t in tweet_df.pre_clean_txt]


#tweet_df['pre_clean_txt'] = [t.translate(str.maketrans('', '', string.punctuation)) for t in tweet_df.pre_clean_txt]
#tweet_df['pre_clean_txt'] = tweet_df.pre_clean_txt.apply(lambda x: x.translate(None, string.digits))

#tweet_df['pre_clean_txt'] = [BeautifulSoup(t['HTML']).get_text().replace('\n',' ') for t in tweet_df.pre_clean_txt]


#tweet_df['pre_clean_txt'] = tweet_df.pre_clean_txt.apply(lambda x: BeautifulSoup(x['HTML']).get_text().replace('\n',' '))
tweet_df.head(100)
# Out:
#     ItemID  Sentiment                                      SentimentText  \
# 0        1          0                       is so sad for my APL frie...
# 1        2          0                     I missed the New Moon trail...
# 2        3          1                            omg its already 7:30 :O
# 3        4          0            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4        5          0           i think mi bf is cheating on me!!!   ...
# 5        6          0                  or i just worry too much?
# 6        7          1                 Juuuuuuuuuuuuuuuuussssst Chillin!!
# 7        8          0         Sunny Again        Work Tomorrow  :-|  ...
# 8        9          1        handed in my uniform today . i miss you ...
# 9       10          1           hmmmm.... i wonder how she my number @-)
# 10      11          0                      I must think about positive..
# 11      12          1        thanks to all the haters up in my face a...
# 12      13          0                     this weekend has sucked so far
# 13      14          0             jb isnt showing in australia any more!
# 14      15          0                               ok thats it you win.
# 15      16          0      &lt;-------- This is the way i feel right ...
# 16      17          0      awhhe man.... I'm completely useless rt no...
# 17      18          1      Feeling strangely fine. Now I'm gonna go l...
# 18      19          0       HUGE roll of thunder just now...SO scary!!!!
# 19      20          0      I just cut my beard off. It's only been gr...
# 20      21          0                               Very sad about Iran.
# 21      22          0                                      wompppp wompp
# 22      23          1      You're the only one who can see this cause...
# 23      24          0     &lt;---Sad level is 3. I was writing a mass...
# 24      25          0     ...  Headed to Hospitol : Had to pull out o...
# 25      26          0     BoRinG   ): whats wrong with him??     Plea...
# 26      27          0     can't be bothered. i wish i could spend the...
# 27      28          0     Feeeling like shit right now. I really want...
# 28      29          1              goodbye exams, HELLO ALCOHOL TONIGHT
# 29      30          0     I didn't realize it was THAT deep. Geez giv...
# ..     ...        ...                                                ...
# 70      71          0        I never thought I'd become second choice...
# 71      72          0    I think I may be too friendly...lol... o wel...
# 72      73          0    I think Manuel (my Basil plant) only has day...
# 73      74          0    I wanna be at home @ church...I wonder wht t...
# 74      75          0                          i wanna make my own pizza
# 75      76          0    i want a 120gb harddrive, or a 37 inch tv, o...
# 76      77          0                                       i want a hug
# 77      78          0                     I want Miley to tour Australia
# 78      79          0    I wanted to sleep in this morning but a mean...
# 79      80          0                    i was too slow to get $1 Up tix
# 80      81          0    I will send sunshine to Northern Ireland, ar...
# 81      82          0    I wish I could go to T4 On The Beach :'(    ...
# 82      83          0    i would be so much happier if the walls of m...
# 83      84          0    idk wat 2 do who can i trust me im sorry 4 a...
# 84      85          0    I'm finding the intercept slope..and banging...
# 85      86          1                     I'm really going to bed now...
# 86      87          0                             im sick  'cough cough'
# 87      88          0    in cab headed to the airport!  going home......
# 88      89          0    In case I feel emo in camp (feeling a wee bi...
# 89      90          1                                 Jin has a twitter.
# 90      91          0                       jonas day is almost over...
# 91      92          0    Jus Got Hom Fr. TDa Funeral... I'm So Sad! I...
# 92      93          1    just gonna smile...cuz it is what it is..and...
# 93      94          1    Just got home, and I got to see my friend Za...
# 94      95          0   - Longest night ever.. ugh! http://tumblr.com...
# 95      96          0    mi momacita won't let me go to my bf's bball...
# 96      97          0    Mom says I have to get a new phone IMMEDIATE...
# 97      98          0    My new car was stolen....by my mother who wa...
# 98      99          0    no hang out with the girls 2day. 2moro, hope...
# 99     100          0    no movie times for sunday!  Rats will have t...
#
#     pre_clean_len                                      pre_clean_txt  \
# 0              61                        is so sad for my apl friend
# 1              51                      i missed the new moon trailer
# 2              37                                 omg its already  o
# 3             132             omgaga im sooo  im gunna cry ive be...
# 4              53           i think mi bf is cheating on me       tt
# 5              42                   or i just worry too much
# 6              41                   juuuuuuuuuuuuuuuuussssst chillin
# 7              61         sunny again        work tomorrow       ...
# 8              53        handed in my uniform today  i miss you a...
# 9              46                  hmmmm i wonder how she my number
# 10             35                        i must think about positive
# 11             61        thanks to all the haters up in my face a...
# 12             36                     this weekend has sucked so far
# 13             43              jb isnt showing in australia any more
# 14             25                                ok thats it you win
# 15             52                   this is the way i feel right now
# 16            101      awhhe man im completely useless rt now fun...
# 17             82      feeling strangely fine now im gonna go lis...
# 18             48              huge roll of thunder just nowso scary
# 19            136      i just cut my beard off its only been grow...
# 20             24                                very sad about iran
# 21             17                                      wompppp wompp
# 22            120      youre the only one who can see this cause ...
# 23            137     sad level is  i was writing a massive blog ...
# 24            134       headed to hospitol  had to pull out of th...
# 25             70     boring    whats wrong with him     please t...
# 26            106     cant be bothered i wish i could spend the r...
# 27            125     feeeling like shit right now i really want ...
# 28             40               goodbye exams hello alcohol tonight
# 29             73     i didnt realize it was that deep geez give ...
# ..            ...                                                ...
# 70             45            i never thought id become second choice
# 71             50            i think i may be too friendlylol o well
# 72             58    i think manuel my basil plant only has days ...
# 73             60    i wanna be at home  churchi wonder wht they ...
# 74             27                          i wanna make my own pizza
# 75             94    i want a gb harddrive or a  inch tv or a new...
# 76             14                                       i want a hug
# 77             32                     i want miley to tour australia
# 78            132    i wanted to sleep in this morning but a mean...
# 79             33                      i was too slow to get  up tix
# 80             80    i will send sunshine to northern ireland are...
# 81            110    i wish i could go to t on the beach     woul...
# 82             75    i would be so much happier if the walls of m...
# 83            134    idk wat  do who can i trust me im sorry  all...
# 84            102    im finding the intercept slopeand banging my...
# 85             32                         im really going to bed now
# 86             24                               im sick  cough cough
# 87             63    in cab headed to the airport  going home chr...
# 88            133    in case i feel emo in camp feeling a wee bit...
# 89             20                                  jin has a twitter
# 90             30                          jonas day is almost over
# 91            146    jus got hom fr tda funeral im so sad i cried...
# 92             86    just gonna smilecuz it is what it isand im n...
# 93            116    just got home and i got to see my friend zah...
# 94             56                            longest night ever ugh
# 95             62    mi momacita wont let me go to my bfs bball g...
# 96             84    mom says i have to get a new phone immediate...
# 97             72    my new car was stolenby my mother who wanted...
# 98             55        no hang out with the girls day moro hope so
# 99            136    no movie times for sunday  rats will have to...
#
#                                        pre_clean_txt1
# 0                         is so sad for my APL friend
# 1                       I missed the New Moon trailer
# 2                               omg its already 730 O
# 3              Omgaga Im sooo  im gunna CRy Ive be...
# 4            i think mi bf is cheating on me       TT
# 5                    or i just worry too much
# 6                    Juuuuuuuuuuuuuuuuussssst Chillin
# 7          Sunny Again        Work Tomorrow       ...
# 8         handed in my uniform today  i miss you a...
# 9                   hmmmm i wonder how she my number
# 10                        I must think about positive
# 11        thanks to all the haters up in my face a...
# 12                     this weekend has sucked so far
# 13              jb isnt showing in australia any more
# 14                                ok thats it you win
# 15                   This is the way i feel right now
# 16      awhhe man Im completely useless rt now Fun...
# 17      Feeling strangely fine Now Im gonna go lis...
# 18              HUGE roll of thunder just nowSO scary
# 19      I just cut my beard off Its only been grow...
# 20                                Very sad about Iran
# 21                                      wompppp wompp
# 22      Youre the only one who can see this cause ...
# 23     Sad level is 3 I was writing a massive blog...
# 24       Headed to Hospitol  Had to pull out of th...
# 25     BoRinG    whats wrong with him     Please t...
# 26     cant be bothered i wish i could spend the r...
# 27     Feeeling like shit right now I really want ...
# 28               goodbye exams HELLO ALCOHOL TONIGHT
# 29     I didnt realize it was THAT deep Geez give ...
# ..                                                ...
# 70            I never thought Id become second choice
# 71            I think I may be too friendlylol o well
# 72    I think Manuel my Basil plant only has days ...
# 73    I wanna be at home  churchI wonder wht they ...
# 74                          i wanna make my own pizza
# 75    i want a 120gb harddrive or a 37 inch tv or ...
# 76                                       i want a hug
# 77                     I want Miley to tour Australia
# 78    I wanted to sleep in this morning but a mean...
# 79                     i was too slow to get 1 Up tix
# 80    I will send sunshine to Northern Ireland are...
# 81    I wish I could go to T4 On The Beach     Wou...
# 82    i would be so much happier if the walls of m...
# 83    idk wat 2 do who can i trust me im sorry 4 a...
# 84    Im finding the intercept slopeand banging my...
# 85                         Im really going to bed now
# 86                               im sick  cough cough
# 87    in cab headed to the airport  going home chr...
# 88    In case I feel emo in camp feeling a wee bit...
# 89                                  Jin has a twitter
# 90                          jonas day is almost over
# 91    Jus Got Hom Fr TDa Funeral Im So Sad I Cried...
# 92    just gonna smilecuz it is what it isand im n...
# 93    Just got home and I got to see my friend Zah...
# 94                            Longest night ever ugh
# 95    mi momacita wont let me go to my bfs bball g...
# 96    Mom says I have to get a new phone IMMEDIATE...
# 97    My new car was stolenby my mother who wanted...
# 98      no hang out with the girls 2day 2moro hope so
# 99    no movie times for sunday  Rats will have to...
#
# [100 rows x 6 columns]

# %%
# dictionary of words
import re 
words_df = pd.DataFrame(tweet_df['pre_clean_txt'].values.tolist(), index=tweet_df.index)

word_dict = {}

for ww in words_df[0]:
    for w in re.findall(r'\w+', ww):
        if w in word_dict: 
            word_dict[w] += 1
        else: 
            word_dict[w] = 1

# wc = [t for t in word_dict]

words_df1 = pd.DataFrame.from_dict(word_dict, orient='index')

file = os.path.join('..', 'Output', 'words.csv' )
#wfile = open(file,"w")
#wfile.writelines(sorted(word_dict.keys())
#wfile.close()
    
#sorted(word_dict.keys())
words_df1.head(100)
words_df1.to_csv(file)
